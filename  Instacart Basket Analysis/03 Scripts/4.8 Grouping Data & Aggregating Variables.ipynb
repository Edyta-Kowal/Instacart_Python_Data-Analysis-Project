# %% [markdown]
# # Exercise 4.8 - Grouping Data & Aggregating Variables

# %% [markdown]
# ## 01. Importing libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing dataframes

# %%
# Create folder path

path = r'/Users/edytakowal/Desktop/Instacart Basket Analysis/02 Data'

# %%
# Import the ords_prods_merged dataframe from the pickle file

ords_prods_merged = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Extract the subset of the dataframe, the first one million rows

df = ords_prods_merged[:1000000]

# %%
# Check the deimension of dataframe

df.shape
# Out:
# (1000000, 18)

# %%
# check the output 

df.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  Unnamed: 0.1  order_id  user_id  \
# 0             19     5.8          1987          1987   3139998      138
# 1             19     5.8          1989          1989   1977647      138
# 2             19     5.8         11433         11433    389851      709
# 3             19     5.8         12198         12198    652770      764
# 4             19     5.8         12200         12200   1813452      764
#
#    order_number  orders_day_of_week  order_hour  days_since_prior_order  \
# ...

# %% [markdown]
# ## 03. Grouping Data with pandas

# %%
# Group dataframe by “product_name” 

df.groupby('product_name')

# %% [markdown]
# ## 04. Aggregating Data with agg()

# %%
# Apply the agg() function to each department_id to obtain the mean values for the “order_number” column.

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# Command above replaced with a command that uses the mean() function to achieve the same results

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %% [markdown]
# ## 05. Performing Multiple Aggregations

# %%
# # Apply the agg() function to each department_id to obtain the mean, min and max values for the “order_number” column

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# ## 06. Aggregating Data with transform()

# %%
# Create a “max_order” column

#ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check the optput 

#ords_prods_merge.head()

# %% [markdown]
# ## 07. Deriving Columns with loc()

# %%
# Create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value

#ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
#ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
#ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check the frequency in 'loyalty_flag' column

#ords_prods_merge['loyalty_flag'].value_counts(dropna = False)

# %%
# Check the output 

#ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)

# %% [markdown]
# # 4.8 Task

# %% [markdown]
# ## 01. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %% [markdown]
# ## 02. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Apply the agg() function to each department_id to obtain the mean values for the “order_number” column.

ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## 03. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# The result from the subset is not significantly different from the result from the whole data frame, on average by 1 order

# %% [markdown]
# ## 04. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Create a “max_order” column

ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value

ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check the frequency in 'loyalty_flag' column

ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check the first 10 rows 

ords_prods_merged[['user_id', 'order_number', 'loyalty_flag']].head(10)
# Out:
#    user_id  order_number      loyalty_flag
# 0      138            28  Regular customer
# 1      138            30  Regular customer
# 2      709             2      New customer
# 3      764             1      New customer
# 4      764             3      New customer
# 5      777            16  Regular customer
# 6      825             3      New customer
# 7      910            12  Regular customer
# 8     1052            10  Regular customer
# 9     1052            15  Regular customer

# %% [markdown]
# ## 05. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Check the df to find useful columns 
ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  Unnamed: 0.1  order_id  user_id  \
# 0             19     5.8          1987          1987   3139998      138
# 1             19     5.8          1989          1989   1977647      138
# 2             19     5.8         11433         11433    389851      709
# 3             19     5.8         12198         12198    652770      764
# 4             19     5.8         12200         12200   1813452      764
#
#    order_number  orders_day_of_week  order_hour  days_since_prior_order  \
# ...

# %%
# Apply the agg() function to each 'loyalty_flag' to obtain the mean values for the 'prices' column

ords_prods_merged.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer    10.386336
# New customer      13.294670
# Regular customer  12.495717

# %% [markdown]
# ## 06. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Create a “avg_product_price” column

ords_prods_merged['avg_product_price'] = ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check the first 5 rows

ords_prods_merged[['user_id', 'avg_product_price']].head()
# Out:
#    user_id  avg_product_price
# 0      138           6.935811
# 1      138           6.935811
# 2      709           7.930208
# 3      764           4.972414
# 4      764           4.972414

# %%
# Create a flag that assigns a “” label to a user ID based on its corresponding max order value

ords_prods_merged.loc[ords_prods_merged['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'
ords_prods_merged.loc[ords_prods_merged['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Check the frequency in 'spending_flag' column

ords_prods_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770746
# High spender      634113
# Name: spending_flag, dtype: int64

# %%
# Check the first 50 rows

ords_prods_merged[['user_id','spending_flag']].head(50)
# Out:
#     user_id spending_flag
# 0       138   Low spender
# 1       138   Low spender
# 2       709   Low spender
# 3       764   Low spender
# 4       764   Low spender
# 5       777   Low spender
# 6       825   Low spender
# 7       910   Low spender
# 8      1052   Low spender
# 9      1052   Low spender
# 10     1379   Low spender
# 11     1480   Low spender
# 12     1480   Low spender
# 13     1480   Low spender
# 14     1494   Low spender
# 15     1494   Low spender
# 16     1494   Low spender
# 17     1540   Low spender
# 18     1540   Low spender
# 19     1540   Low spender
# 20     1540   Low spender
# 21     1540   Low spender
# 22     1540   Low spender
# 23     1540   Low spender
# 24     1540   Low spender
# 25     1540   Low spender
# 26     1540   Low spender
# 27     1540   Low spender
# 28     1540   Low spender
# 29     1540   Low spender
# 30     1540   Low spender
# 31     1540   Low spender
# 32     1540   Low spender
# 33     1540   Low spender
# ...

# %%
# Check user with user_id = 1

ords_prods_merged[ords_prods_merged['user_id'] == 1]
# Out:
#           Unnamed: 0_x  product_id                             product_name  \
# 92368              195         196                                     Soda
# 92369              195         196                                     Soda
# 92370              195         196                                     Soda
# 92371              195         196                                     Soda
# 92372              195         196                                     Soda
# 92373              195         196                                     Soda
# 92374              195         196                                     Soda
# 92375              195         196                                     Soda
# 92376              195         196                                     Soda
# 92377              195         196                                     Soda
# 5971715          10258       10258                               Pistachios
# ...

# %% [markdown]
# ## 08. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Create a 'median_order_freq' column

ords_prods_merged['median_order_freq'] = ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Check the first 5 rows 


ords_prods_merged[['user_id', 'median_order_freq']].head()
# Out:
#    user_id  median_order_freq
# 0      138                8.0
# 1      138                8.0
# 2      709                8.0
# 3      764                9.0
# 4      764                9.0

# %%
# Create a flag that assigns a “frequency” label to a user ID based on 
# regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

ords_prods_merged.loc[ords_prods_merged['median_order_freq'] > 20, 'freq_flag'] = 'Non-frequent customer'
ords_prods_merged.loc[(ords_prods_merged['median_order_freq'] <= 20) & (ords_prods_merged['median_order_freq'] > 10), 'freq_flag'] = 'Regular customer'
ords_prods_merged.loc[ords_prods_merged['median_order_freq'] <= 10, 'freq_flag'] = 'Frequent customer'

# %%
# Check the frequency of 'frequency flag' column

ords_prods_merged['freq_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: freq_flag, dtype: int64

# %%
# Check the first 50 rows 

ords_prods_merged[['user_id','freq_flag']].head(50)
# Out:
#     user_id              freq_flag
# 0       138      Frequent customer
# 1       138      Frequent customer
# 2       709      Frequent customer
# 3       764      Frequent customer
# 4       764      Frequent customer
# 5       777       Regular customer
# 6       825       Regular customer
# 7       910      Frequent customer
# 8      1052      Frequent customer
# 9      1052      Frequent customer
# 10     1379       Regular customer
# 11     1480      Frequent customer
# 12     1480      Frequent customer
# 13     1480      Frequent customer
# 14     1494      Frequent customer
# 15     1494      Frequent customer
# 16     1494      Frequent customer
# 17     1540      Frequent customer
# 18     1540      Frequent customer
# 19     1540      Frequent customer
# 20     1540      Frequent customer
# 21     1540      Frequent customer
# 22     1540      Frequent customer
# 23     1540      Frequent customer
# 24     1540      Frequent customer
# 25     1540      Frequent customer
# ...

# %%
# Check the output 

ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  Unnamed: 0.1  order_id  user_id  ...  \
# 0             19     5.8          1987          1987   3139998      138  ...
# 1             19     5.8          1989          1989   1977647      138  ...
# 2             19     5.8         11433         11433    389851      709  ...
# 3             19     5.8         12198         12198    652770      764  ...
# 4             19     5.8         12200         12200   1813452      764  ...
#
#    add_to_cart_order  reordered  _merge  exists  max_order      loyalty_flag  \
# ...

# %% [markdown]
# ## 09. Ensure your notebook is clean and structured and that your code is well commented.

# %% [markdown]
# ## Outstanding values from Exercise 4.9

# %%
# Determine whether there are any values above the “normal” price of a supermarket item

ords_prods_merged.loc[ords_prods_merged['prices'] > 100]
# Out:
#           Unnamed: 0_x  product_id                      product_name  \
# 13100147         21554       21553  Lowfat 2% Milkfat Cottage Cheese
# 13100148         21554       21553  Lowfat 2% Milkfat Cottage Cheese
# 13100149         21554       21553  Lowfat 2% Milkfat Cottage Cheese
# 13100150         21554       21553  Lowfat 2% Milkfat Cottage Cheese
# 13100151         21554       21553  Lowfat 2% Milkfat Cottage Cheese
# ...                ...         ...                               ...
# 21786876         33666       33664             2 % Reduced Fat  Milk
# 21786877         33666       33664             2 % Reduced Fat  Milk
# 21786878         33666       33664             2 % Reduced Fat  Milk
# 21786879         33666       33664             2 % Reduced Fat  Milk
# 21786880         33666       33664             2 % Reduced Fat  Milk
#
#           aisle_id  department_id   prices  Unnamed: 0_y  Unnamed: 0.1  \
# ...

# %%
# Mark the outstanding values as missing

ords_prods_merged.loc[ords_prods_merged['prices'] > 100, 'prices'] = np.nan

# %%
# Check max value after changes

ords_prods_merged['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ## 10. Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Export ords_prods_merged as orders_products_merged_new.pkl

ords_prods_merged.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged_new.pkl'))
